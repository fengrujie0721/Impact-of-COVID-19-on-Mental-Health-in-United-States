# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
# Files to Load
file1_to_load = "Resources/us_states.csv"
file2_to_load = "Resources/Anxiety_data.csv"

# Read CSV Files and store into Pandas data frames
covid_data = pd.read_csv(file1_to_load)
anxiety_data = pd.read_csv(file2_to_load)

#Display DataFrames for Covid and Anxiety data
display('Covid Data:', covid_data.head())
display('Anxiety Data:',anxiety_data.head())
# Out:
# 'Covid Data:'
#         date       state  fips  cases  deaths
# 0  1/21/2020  Washington    53      1       0
# 1  1/22/2020  Washington    53      1       0
# 2  1/23/2020  Washington    53      1       0
# 3  1/24/2020    Illinois    17      1       0
# 4  1/24/2020  Washington    53      1       0
# 'Anxiety Data:'
#                          Indicator              Group          State  \
# 0  Symptoms of Depressive Disorder  National Estimate  United States
# 1  Symptoms of Depressive Disorder             By Age  United States
# 2  Symptoms of Depressive Disorder             By Age  United States
# 3  Symptoms of Depressive Disorder             By Age  United States
# 4  Symptoms of Depressive Disorder             By Age  United States
#
#         Subgroup Phase  Time Period Time Period Label Time Period Start Date  \
# 0  United States     1            1    Apr 23 - May 5         4/23/2020 0:00
# 1  18 - 29 years     1            1    Apr 23 - May 5         4/23/2020 0:00
# 2  30 - 39 years     1            1    Apr 23 - May 5         4/23/2020 0:00
# 3  40 - 49 years     1            1    Apr 23 - May 5         4/23/2020 0:00
# 4  50 - 59 years     1            1    Apr 23 - May 5         4/23/2020 0:00
#
#   Time Period End Date  Value  Low CI  High CI Confidence Interval  \
# 0        5/5/2020 0:00   23.5    22.7     24.3         22.7 - 24.3
# 1        5/5/2020 0:00   32.7    30.2     35.2         30.2 - 35.2
# 2        5/5/2020 0:00   25.7    24.1     27.3         24.1 - 27.3
# 3        5/5/2020 0:00   24.8    23.3     26.2         23.3 - 26.2
# 4        5/5/2020 0:00   23.2    21.5     25.0         21.5 - 25.0
#
#   Quartile Range
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
del covid_data['fips']
covid_data
# Out:
#             date          state   cases  deaths
# 0      1/21/2020     Washington       1       0
# 1      1/22/2020     Washington       1       0
# 2      1/23/2020     Washington       1       0
# 3      1/24/2020       Illinois       1       0
# 4      1/24/2020     Washington       1       0
# ...          ...            ...     ...     ...
# 23054  4/25/2021       Virginia  654210   10691
# 23055  4/25/2021     Washington  397006    5478
# 23056  4/25/2021  West Virginia  151382    2821
# 23057  4/25/2021      Wisconsin  656668    7473
# 23058  4/25/2021        Wyoming   57696     705
#
# [23059 rows x 4 columns]

# %%
del anxiety_data['Group']
del anxiety_data['Subgroup']
del anxiety_data['Phase']
del anxiety_data['Time Period']
del anxiety_data['Time Period Label']
del anxiety_data['Time Period End Date']
del anxiety_data['Low CI']
del anxiety_data['High CI']
del anxiety_data['Confidence Interval']
del anxiety_data['Quartile Range']

#change the date format of anxiety_data to match covid_data's
anxiety_data['Time Period Start Date'] = anxiety_data['Time Period Start Date'].apply(lambda dateStr:dateStr.split()[0])

#change column names to assist merge and be meaningful
anxiety_data_renamed = anxiety_data.rename(columns={'State':'state',"Indicator":"mental disorder","Value":"frequency of mental disorder","Time Period Start Date":"date"})
anxiety_data_renamed
# Out:
#                                         mental disorder          state  \
# 0                       Symptoms of Depressive Disorder  United States
# 1                       Symptoms of Depressive Disorder  United States
# 2                       Symptoms of Depressive Disorder  United States
# 3                       Symptoms of Depressive Disorder  United States
# 4                       Symptoms of Depressive Disorder  United States
# ...                                                 ...            ...
# 5779  Symptoms of Anxiety Disorder or Depressive Dis...       Virginia
# 5780  Symptoms of Anxiety Disorder or Depressive Dis...     Washington
# 5781  Symptoms of Anxiety Disorder or Depressive Dis...  West Virginia
# 5782  Symptoms of Anxiety Disorder or Depressive Dis...      Wisconsin
# 5783  Symptoms of Anxiety Disorder or Depressive Dis...        Wyoming
#
#            date  frequency of mental disorder
# 0     4/23/2020                          23.5
# 1     4/23/2020                          32.7
# 2     4/23/2020                          25.7
# 3     4/23/2020                          24.8
# 4     4/23/2020                          23.2
# ...         ...                           ...
# 5779  3/17/2021                          31.4
# 5780  3/17/2021                          35.6
# 5781  3/17/2021                          41.0
# 5782  3/17/2021                          32.3
# 5783  3/17/2021                          35.6
#
# [5784 rows x 4 columns]

# %%
#merge data based on states
merged_data = covid_data.merge(anxiety_data_renamed,how="inner", on = ["state","date"])
merged_data
# Out:
#            date      state   cases  deaths  \
# 0     4/23/2020    Alabama    5832     197
# 1     4/23/2020    Alabama    5832     197
# 2     4/23/2020    Alabama    5832     197
# 3     4/23/2020     Alaska     335       7
# 4     4/23/2020     Alaska     335       7
# ...         ...        ...     ...     ...
# 4126  3/17/2021  Wisconsin  627266    7203
# 4127  3/17/2021  Wisconsin  627266    7203
# 4128  3/17/2021    Wyoming   55449     693
# 4129  3/17/2021    Wyoming   55449     693
# 4130  3/17/2021    Wyoming   55449     693
#
#                                         mental disorder  \
# 0                       Symptoms of Depressive Disorder
# 1                          Symptoms of Anxiety Disorder
# 2     Symptoms of Anxiety Disorder or Depressive Dis...
# 3                       Symptoms of Depressive Disorder
# 4                          Symptoms of Anxiety Disorder
# ...                                                 ...
# 4126                       Symptoms of Anxiety Disorder
# 4127  Symptoms of Anxiety Disorder or Depressive Dis...
# 4128                    Symptoms of Depressive Disorder
# 4129                       Symptoms of Anxiety Disorder
# 4130  Symptoms of Anxiety Disorder or Depressive Dis...
#
#       frequency of mental disorder
# 0                             18.6
# 1                             25.6
# 2                             30.3
# 3                             19.2
# 4                             27.7
# ...                            ...
# 4126                          25.9
# 4127                          32.3
# 4128                          24.2
# 4129                          30.1
# 4130                          35.6
#
# [4131 rows x 6 columns]

# %%
#Added new colum for month to calculate average frequency by month
merged_data["date_new"]=pd.to_datetime(merged_data["date"], format='%m/%d/%Y')
merged_data["month"]=pd.DatetimeIndex(merged_data["date_new"]).month
merged_data
# Out:
#            date      state   cases  deaths  \
# 0     4/23/2020    Alabama    5832     197
# 1     4/23/2020    Alabama    5832     197
# 2     4/23/2020    Alabama    5832     197
# 3     4/23/2020     Alaska     335       7
# 4     4/23/2020     Alaska     335       7
# ...         ...        ...     ...     ...
# 4126  3/17/2021  Wisconsin  627266    7203
# 4127  3/17/2021  Wisconsin  627266    7203
# 4128  3/17/2021    Wyoming   55449     693
# 4129  3/17/2021    Wyoming   55449     693
# 4130  3/17/2021    Wyoming   55449     693
#
#                                         mental disorder  \
# 0                       Symptoms of Depressive Disorder
# 1                          Symptoms of Anxiety Disorder
# 2     Symptoms of Anxiety Disorder or Depressive Dis...
# 3                       Symptoms of Depressive Disorder
# 4                          Symptoms of Anxiety Disorder
# ...                                                 ...
# 4126                       Symptoms of Anxiety Disorder
# 4127  Symptoms of Anxiety Disorder or Depressive Dis...
# 4128                    Symptoms of Depressive Disorder
# 4129                       Symptoms of Anxiety Disorder
# 4130  Symptoms of Anxiety Disorder or Depressive Dis...
#
#       frequency of mental disorder   date_new  month
# 0                             18.6 2020-04-23      4
# 1                             25.6 2020-04-23      4
# 2                             30.3 2020-04-23      4
# 3                             19.2 2020-04-23      4
# 4                             27.7 2020-04-23      4
# ...                            ...        ...    ...
# 4126                          25.9 2021-03-17      3
# 4127                          32.3 2021-03-17      3
# 4128                          24.2 2021-03-17      3
# 4129                          30.1 2021-03-17      3
# 4130                          35.6 2021-03-17      3
#
# [4131 rows x 8 columns]

# %%
#Calculate average frequency per month
month_groupby = merged_data.groupby(['month'])
avg_anx_month = month_groupby['frequency of mental disorder'].mean()
monthly_df = pd.DataFrame({"average frequency by month": avg_anx_month})
monthly_df
# Out:
#        average frequency by month
# month
# 1                       34.342157
# 2                       32.553595
# 3                       30.043464
# 4                       28.807190
# 5                       28.411275
# 6                       30.277614
# 7                       33.571678
# 8                       29.809804
# 9                       30.486057
# 10                      33.137255
# 11                      35.361111
# 12                      35.790850

# %%
#Create data frame for monthly average US anxiety 
US_Anxiety_bymonth_df = pd.DataFrame({
    "Months" : ["April 2020", "May", "Jun", "July", "August", "September", "October", "November", "December", "January 2021", "February 2021", "March 2021"],
    "Frequency of mental disorder" :[34.34, 32.55, 30.04, 28.81, 28.41, 30.28, 33.57, 29.81, 30.49, 33.14, 35.36, 35.79]
})
US_Anxiety_bymonth_df
# Out:
#            Months  Frequency of mental disorder
# 0      April 2020                         34.34
# 1             May                         32.55
# 2             Jun                         30.04
# 3            July                         28.81
# 4          August                         28.41
# 5       September                         30.28
# 6         October                         33.57
# 7        November                         29.81
# 8        December                         30.49
# 9    January 2021                         33.14
# 10  February 2021                         35.36
# 11     March 2021                         35.79

# %%
#Create chart for US anxiety change by months
chart_anx = pd.DataFrame(US_Anxiety_bymonth_df.groupby(["Months"]).count()).reset_index()
chart_anx_df = US_Anxiety_bymonth_df[["Months", "Frequency of mental disorder"]]
chart_anx_df = chart_anx_df.set_index("Months")

chart_anx_df.plot(kind="line", figsize=(20,10))
plt.title("US anxiety change by months")
plt.ylabel("Frequency of mental disorder")
plt.savefig('Images/US anxiety change by month.png')
plt.show()

# %%
#Create dataframe for average anxiety by state
anx_group_state_df = merged_data.groupby(["state"])
anx_mean_state = anx_group_state_df.mean()
anx_mean_state.head()
# Out:
#                    cases        deaths  frequency of mental disorder     month
# state
# Alabama     1.739869e+05   3081.555556                     32.496296  6.296296
# Alaska      1.789378e+04     86.259259                     31.638272  6.296296
# Arizona     2.708545e+05   5512.000000                     33.493827  6.296296
# Arkansas    1.061795e+05   1719.148148                     34.324691  6.296296
# California  1.112002e+06  17291.148148                     34.827160  6.296296

# %%
del anx_mean_state['cases']
del anx_mean_state['deaths']
del anx_mean_state['month']
anx_mean_state.head()
# Out:
#             frequency of mental disorder
# state
# Alabama                        32.496296
# Alaska                         31.638272
# Arizona                        33.493827
# Arkansas                       34.324691
# California                     34.827160

# %%
#Create data frame for total number of cases and deaths as of 03/01/2020
covid_030120_df = covid_data.loc[covid_data["date"] =="3/1/2020", :]
covid_030120_df.head()
# Out:
#          date          state  cases  deaths
# 240  3/1/2020        Arizona      1       0
# 241  3/1/2020     California     33       0
# 242  3/1/2020        Florida      2       0
# 243  3/1/2020       Illinois      3       0
# 244  3/1/2020  Massachusetts      1       0

# %%
# Sort the DataFrame by "deaths" in ascending order
covid_030120_df = covid_030120_df.sort_values("deaths")
covid_030120_df
# Out:
#          date          state  cases  deaths
# 240  3/1/2020        Arizona      1       0
# 241  3/1/2020     California     33       0
# 242  3/1/2020        Florida      2       0
# 243  3/1/2020       Illinois      3       0
# 244  3/1/2020  Massachusetts      1       0
# 245  3/1/2020       Nebraska     13       0
# 246  3/1/2020       New York      1       0
# 247  3/1/2020         Oregon      2       0
# 248  3/1/2020   Rhode Island      2       0
# 249  3/1/2020          Texas     11       0
# 250  3/1/2020           Utah      1       0
# 252  3/1/2020      Wisconsin      1       0
# 251  3/1/2020     Washington     17       3

# %%
# Calculate total deaths as of 03/01/2020
total_deaths_030120 = (covid_030120_df["deaths"]).sum()
total_deaths_030120_df = pd.DataFrame({"Total deaths from COVID-19 as of 03/01/2020 in US": [total_deaths_030120]})
total_deaths_030120_df
# Out:
#    Total deaths from COVID-19 as of 03/01/2020 in US
# 0                                                  3

# %%
#Create chart for total deaths by each state as of 03/01/2020
chart_030120 = pd.DataFrame(covid_030120_df.groupby(["state"]).count()).reset_index()
chart_030120_df = covid_030120_df[["state", "deaths"]]
chart_030120_df = chart_030120_df.set_index("state")

chart_030120_df.plot(kind="bar", figsize=(20,10))
plt.title("Total deaths from COVID-19 as of 03/01/2020 by each state")
plt.ylabel("Total deaths")
plt.annotate("US Total deaths from COVID: 3",(0,3), fontsize=25, color="red")
plt.savefig('Images/US Total deaths from COVID-19 as of 03-01-2020.png')
plt.show()

# %%
#Create data frame for total number of cases and deaths as of 04/30/2020
covid_043020_df = covid_data.loc[covid_data["date"] =="4/30/2020", :]
covid_043020_df.head()
# Out:
#            date       state  cases  deaths
# 3204  4/30/2020     Alabama   7068     272
# 3205  4/30/2020      Alaska    353       7
# 3206  4/30/2020     Arizona   7648     320
# 3207  4/30/2020    Arkansas   3281      61
# 3208  4/30/2020  California  50470    2057

# %%
# Sort the DataFrame by "deaths" in ascending order
covid_043020_df = covid_043020_df.sort_values("deaths")
covid_043020_df
# Out:
#            date                     state   cases  deaths
# 3240  4/30/2020  Northern Mariana Islands      14       2
# 3253  4/30/2020            Virgin Islands      66       4
# 3215  4/30/2020                      Guam    1115       6
# 3258  4/30/2020                   Wyoming     559       7
# 3205  4/30/2020                    Alaska     353       7
# 3216  4/30/2020                    Hawaii     609      16
# 3231  4/30/2020                   Montana     452      16
# 3248  4/30/2020              South Dakota    2450      17
# 3239  4/30/2020              North Dakota    1067      19
# 3256  4/30/2020             West Virginia    1126      44
# 3251  4/30/2020                      Utah    4672      46
# 3252  4/30/2020                   Vermont     866      48
# 3224  4/30/2020                     Maine    1095      53
# 3207  4/30/2020                  Arkansas    3281      61
# 3217  4/30/2020                     Idaho    2016      63
# 3232  4/30/2020                  Nebraska    4332      70
# 3234  4/30/2020             New Hampshire    2146      72
# 3245  4/30/2020               Puerto Rico    1537      92
# 3243  4/30/2020                    Oregon    2510     103
# 3236  4/30/2020                New Mexico    3411     123
# 3221  4/30/2020                    Kansas    4305     133
# 3211  4/30/2020                  Delaware    4734     152
# 3220  4/30/2020                      Iowa    7145     162
# 3249  4/30/2020                 Tennessee   10506     200
# 3242  4/30/2020                  Oklahoma    3618     222
# 3212  4/30/2020      District of Columbia    4323     224
# 3222  4/30/2020                  Kentucky    4708     240
# 3233  4/30/2020                    Nevada    5053     243
# 3247  4/30/2020            South Carolina    6095     244
# 3229  4/30/2020               Mississippi    6815     261
# 3246  4/30/2020              Rhode Island    8621     266
# 3204  4/30/2020                   Alabama    7068     272
# 3257  4/30/2020                 Wisconsin    6973     316
# 3206  4/30/2020                   Arizona    7648     320
# 3230  4/30/2020                  Missouri    7563     341
# 3228  4/30/2020                 Minnesota    5136     343
# 3238  4/30/2020            North Carolina   10507     385
# 3254  4/30/2020                  Virginia   15846     552
# 3209  4/30/2020                  Colorado   15207     775
# 3255  4/30/2020                Washington   14814     822
# 3250  4/30/2020                     Texas   29072     828
# 3241  4/30/2020                      Ohio   18027     975
# 3219  4/30/2020                   Indiana   18099    1114
# 3214  4/30/2020                   Georgia   25431    1121
# 3225  4/30/2020                  Maryland   21825    1139
# 3213  4/30/2020                   Florida   33683    1267
# 3223  4/30/2020                 Louisiana   28044    1905
# 3208  4/30/2020                California   50470    2057
# 3210  4/30/2020               Connecticut   27700    2257
# 3218  4/30/2020                  Illinois   52918    2361
# 3244  4/30/2020              Pennsylvania   48224    2580
# 3226  4/30/2020             Massachusetts   62205    3562
# 3227  4/30/2020                  Michigan   41348    3788
# 3235  4/30/2020                New Jersey  118652    7228
# 3237  4/30/2020                  New York  309696   23616

# %%
# Calculate total deaths as of 04/30/2020
total_deaths_043020 = (covid_043020_df["deaths"]).sum()
total_deaths_043020_df = pd.DataFrame({"Total deaths from COVID-19 as of 04/30/2020 in US": [total_deaths_043020]})
total_deaths_043020_df
# Out:
#    Total deaths from COVID-19 as of 04/30/2020 in US
# 0                                              63140

# %%
#Create chart for total deaths by each state as of 04/30/2020
chart_043020 = pd.DataFrame(covid_043020_df.groupby(["state"]).count()).reset_index()
chart_043020_df = covid_043020_df[["state", "deaths"]]
chart_043020_df = chart_043020_df.set_index("state")

chart_043020_df.plot(kind="bar", figsize=(20,10))
plt.title("Total deaths from COVID-19 as of 04/30/2020 by each state")
plt.ylabel("Total deaths")
plt.annotate("US Total deaths from COVID: 63,140",(1,23000), fontsize=25, color="red")
plt.savefig('Images/US Total deaths from COVID-19 as of 04-30-2020.png')
plt.show()

# %%
#Create data frame for total number of cases and deaths as of 01/01/2021
covid_010121_df = covid_data.loc[covid_data["date"] =="1/1/2021", :]
covid_010121_df.head()
# Out:
#            date       state    cases  deaths
# 16734  1/1/2021     Alabama   365747    4872
# 16735  1/1/2021      Alaska    46740     198
# 16736  1/1/2021     Arizona   530267    9015
# 16737  1/1/2021    Arkansas   229442    3711
# 16738  1/1/2021  California  2345726   26236

# %%
# Sort the DataFrame by "deaths" in ascending order
covid_010121_df = covid_010121_df.sort_values("deaths")
covid_010121_df
# Out:
#            date                     state    cases  deaths
# 16770  1/1/2021  Northern Mariana Islands      122       2
# 16783  1/1/2021            Virgin Islands     2036      23
# 16745  1/1/2021                      Guam     8295     123
# 16782  1/1/2021                   Vermont     7412     136
# 16735  1/1/2021                    Alaska    46740     198
# 16746  1/1/2021                    Hawaii    21736     287
# 16754  1/1/2021                     Maine    24201     347
# 16788  1/1/2021                   Wyoming    44409     438
# 16764  1/1/2021             New Hampshire    44028     759
# 16742  1/1/2021      District of Columbia    29252     788
# 16741  1/1/2021                  Delaware    58064     930
# 16761  1/1/2021                   Montana    81701     962
# 16781  1/1/2021                      Utah   276612    1273
# 16769  1/1/2021              North Dakota    92777    1316
# 16786  1/1/2021             West Virginia    87820    1361
# 16747  1/1/2021                     Idaho   141388    1438
# 16778  1/1/2021              South Dakota    99164    1488
# 16773  1/1/2021                    Oregon   115377    1501
# 16775  1/1/2021               Puerto Rico   110669    1521
# 16762  1/1/2021                  Nebraska   168567    1707
# 16776  1/1/2021              Rhode Island    87949    1777
# 16772  1/1/2021                  Oklahoma   290936    2489
# 16766  1/1/2021                New Mexico   144142    2504
# 16751  1/1/2021                    Kansas   230352    2879
# 16752  1/1/2021                  Kentucky   269470    2956
# 16763  1/1/2021                    Nevada   227046    3146
# 16785  1/1/2021                Washington   251585    3523
# 16737  1/1/2021                  Arkansas   229442    3711
# 16750  1/1/2021                      Iowa   282980    3898
# 16759  1/1/2021               Mississippi   218386    4816
# 16734  1/1/2021                   Alabama   365747    4872
# 16739  1/1/2021                  Colorado   338357    4936
# 16784  1/1/2021                  Virginia   354766    5081
# 16787  1/1/2021                 Wisconsin   522523    5257
# 16777  1/1/2021            South Carolina   307507    5296
# 16758  1/1/2021                 Minnesota   415361    5382
# 16760  1/1/2021                  Missouri   421217    5906
# 16755  1/1/2021                  Maryland   280387    5942
# 16740  1/1/2021               Connecticut   185708    5995
# 16768  1/1/2021            North Carolina   543976    6819
# 16779  1/1/2021                 Tennessee   572579    6846
# 16753  1/1/2021                 Louisiana   315275    7488
# 16749  1/1/2021                   Indiana   520750    8371
# 16771  1/1/2021                      Ohio   700380    8962
# 16736  1/1/2021                   Arizona   530267    9015
# 16744  1/1/2021                   Georgia   654950   10610
# 16756  1/1/2021             Massachusetts   375178   12423
# 16757  1/1/2021                  Michigan   527376   13011
# 16774  1/1/2021              Pennsylvania   652952   16247
# 16748  1/1/2021                  Illinois   966287   17979
# 16765  1/1/2021                New Jersey   484882   19160
# 16743  1/1/2021                   Florida  1323307   21672
# 16738  1/1/2021                California  2345726   26236
# 16780  1/1/2021                     Texas  1779961   28434
# 16767  1/1/2021                  New York   996073   37733

# %%
# Calculate total deaths as of 01/01/2021
total_deaths_010121 = (covid_010121_df["deaths"]).sum()
total_deaths_010121_df = pd.DataFrame({"Total deaths from COVID-19 as of 01/01/2021 in US": [total_deaths_010121]})
total_deaths_010121_df
# Out:
#    Total deaths from COVID-19 as of 01/01/2021 in US
# 0                                             347970

# %%
#Create chart for total deaths by each state as of 01/01/2021
chart_010121 = pd.DataFrame(covid_010121_df.groupby(["state"]).count()).reset_index()
chart_010121_df = covid_010121_df[["state", "deaths"]]
chart_010121_df = chart_010121_df.set_index("state")

chart_010121_df.plot(kind="bar", figsize=(20,10))
plt.title("Total deaths from COVID-19 as of 01/01/2021 by each state")
plt.ylabel("Total deaths")
plt.annotate("US Total deaths from COVID: 347,970",(1,35000), fontsize=25, color="red")
plt.savefig('Images/US Total deaths from COVID-19 as of 01-01-2021.png')
plt.show()

# %%
#Create data frame for total number of cases and deaths as of 04/25/2021
covid_042521_df = covid_data.loc[covid_data["date"] =="4/25/2021", :]
covid_042521_df.head()
# Out:
#             date       state    cases  deaths
# 23004  4/25/2021     Alabama   526131   10851
# 23005  4/25/2021      Alaska    66518     318
# 23006  4/25/2021     Arizona   858737   17268
# 23007  4/25/2021    Arkansas   334706    5718
# 23008  4/25/2021  California  3731677   61434

# %%
# Sort the DataFrame by "deaths" in ascending order
covid_042521_df = covid_042521_df.sort_values("deaths")
covid_042521_df
# Out:
#             date                     state    cases  deaths
# 23040  4/25/2021  Northern Mariana Islands      164       2
# 23053  4/25/2021            Virgin Islands     3068      27
# 23015  4/25/2021                      Guam     8884     137
# 23052  4/25/2021                   Vermont    22576     244
# 23005  4/25/2021                    Alaska    66518     318
# 23016  4/25/2021                    Hawaii    32284     475
# 23058  4/25/2021                   Wyoming    57696     705
# 23024  4/25/2021                     Maine    59776     772
# 23012  4/25/2021      District of Columbia    47323    1099
# 23034  4/25/2021             New Hampshire    93821    1284
# 23039  4/25/2021              North Dakota   106719    1517
# 23031  4/25/2021                   Montana   108170    1563
# 23011  4/25/2021                  Delaware   103222    1616
# 23048  4/25/2021              South Dakota   121986    1958
# 23017  4/25/2021                     Idaho   186300    2033
# 23051  4/25/2021                      Utah   395495    2182
# 23045  4/25/2021               Puerto Rico   162074    2264
# 23032  4/25/2021                  Nebraska   218732    2358
# 23043  4/25/2021                    Oregon   180700    2497
# 23046  4/25/2021              Rhode Island   146324    2660
# 23056  4/25/2021             West Virginia   151382    2821
# 23036  4/25/2021                New Mexico   196221    4026
# 23021  4/25/2021                    Kansas   309544    5009
# 23033  4/25/2021                    Nevada   312840    5422
# 23055  4/25/2021                Washington   397006    5478
# 23007  4/25/2021                  Arkansas   334706    5718
# 23020  4/25/2021                      Iowa   362923    5927
# 23009  4/25/2021                  Colorado   504495    6388
# 23022  4/25/2021                  Kentucky   444211    6557
# 23042  4/25/2021                  Oklahoma   446550    6716
# 23028  4/25/2021                 Minnesota   568321    7157
# 23029  4/25/2021               Mississippi   310349    7175
# 23057  4/25/2021                 Wisconsin   656668    7473
# 23010  4/25/2021               Connecticut   334766    8047
# 23025  4/25/2021                  Maryland   443443    8661
# 23030  4/25/2021                  Missouri   597547    9180
# 23047  4/25/2021            South Carolina   574985    9430
# 23023  4/25/2021                 Louisiana   455541   10336
# 23054  4/25/2021                  Virginia   654210   10691
# 23004  4/25/2021                   Alabama   526131   10851
# 23049  4/25/2021                 Tennessee   826672   12045
# 23038  4/25/2021            North Carolina   963886   12553
# 23019  4/25/2021                   Indiana   718090   13274
# 23006  4/25/2021                   Arizona   858737   17268
# 23026  4/25/2021             Massachusetts   682784   17550
# 23027  4/25/2021                  Michigan   911145   18398
# 23041  4/25/2021                      Ohio  1064306   19122
# 23014  4/25/2021                   Georgia  1069495   19357
# 23018  4/25/2021                  Illinois  1324610   24139
# 23035  4/25/2021                New Jersey   997891   25380
# 23044  4/25/2021              Pennsylvania  1138529   26038
# 23013  4/25/2021                   Florida  2208576   34847
# 23050  4/25/2021                     Texas  2874344   50103
# 23037  4/25/2021                  New York  2029307   51471
# 23008  4/25/2021                California  3731677   61434

# %%
# Calculate total deaths as of 04/25/2021
total_deaths_042521 = (covid_042521_df["deaths"]).sum()
total_deaths_042521_df = pd.DataFrame({"Total deaths from COVID-19 as of 04/25/2021 in US": [total_deaths_042521]})
total_deaths_042521_df
# Out:
#    Total deaths from COVID-19 as of 04/25/2021 in US
# 0                                             571753

# %%
#Create chart for total deaths by each state as of 04/25/2021
chart_042521 = pd.DataFrame(covid_042521_df.groupby(["state"]).count()).reset_index()
chart_042521_df = covid_042521_df[["state", "deaths"]]
chart_042521_df = chart_042521_df.set_index("state")

chart_042521_df.plot(kind="bar", figsize=(20,10))
plt.title("Total deaths from COVID-19 as of 04/25/2021 by each state")
plt.annotate("US Total deaths from COVID: 571,753",(1,60000), fontsize=25, color="red")
plt.savefig('Images/US Total deaths from COVID-19 as of 04-25-2021.png')
plt.show()
