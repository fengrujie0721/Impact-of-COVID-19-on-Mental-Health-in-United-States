# %%
import pandas as pd
# File to Load
file_to_load = "Resources/Covid_deaths.csv"

# Read CSV File and store into Pandas data frame
covid_data = pd.read_csv(file_to_load)
covid_data

# %%
del anx_data['Group']
del anx_data['Subgroup']
del anx_data['Phase']
del anx_data['Time Period']
del anx_data['Time Period Label']
del anx_data['Time Period End Date']
del anx_data['Low CI']
del anx_data['High CI']
del anx_data['Confidence Interval']
del anx_data['Quartile Range']
anx_data
# Out:
#                                               Indicator          State  \
# 0                       Symptoms of Depressive Disorder  United States
# 1                       Symptoms of Depressive Disorder  United States
# 2                       Symptoms of Depressive Disorder  United States
# 3                       Symptoms of Depressive Disorder  United States
# 4                       Symptoms of Depressive Disorder  United States
# ...                                                 ...            ...
# 5779  Symptoms of Anxiety Disorder or Depressive Dis...       Virginia
# 5780  Symptoms of Anxiety Disorder or Depressive Dis...     Washington
# 5781  Symptoms of Anxiety Disorder or Depressive Dis...  West Virginia
# 5782  Symptoms of Anxiety Disorder or Depressive Dis...      Wisconsin
# 5783  Symptoms of Anxiety Disorder or Depressive Dis...        Wyoming
#
#      Time Period Start Date  Value
# 0            4/23/2020 0:00   23.5
# 1            4/23/2020 0:00   32.7
# ...

# %%
# Collect a list of all the unique values in "date"
anx_data["Time Period Start Date"].unique()
# Out:
# array(['4/23/2020 0:00', '5/7/2020 0:00', '5/14/2020 0:00',
#        '5/21/2020 0:00', '5/28/2020 0:00', '6/4/2020 0:00',
#        '6/11/2020 0:00', '6/18/2020 0:00', '6/25/2020 0:00',
#        '7/2/2020 0:00', '7/9/2020 0:00', '7/16/2020 0:00',
#        '7/22/2020 0:00', '8/19/2020 0:00', '9/2/2020 0:00',
#        '9/16/2020 0:00', '9/30/2020 0:00', '10/14/2020 0:00',
#        '10/28/2020 0:00', '11/11/2020 0:00', '11/25/2020 0:00',
#        '12/9/2020 0:00', '12/22/2020 0:00', '1/6/2021 0:00',
#        '1/20/2021 0:00', '2/3/2021 0:00', '2/17/2021 0:00',
#        '3/3/2021 0:00', '3/17/2021 0:00'], dtype=object)

# %%
# Looking only at 04/23/2020
anx_042320_df = anx_data.loc[anx_data["Time Period Start Date"] == "4/23/2020 0:00", :]
anx_042320_df
# Out:
#                                              Indicator          State  \
# 0                      Symptoms of Depressive Disorder  United States
# 1                      Symptoms of Depressive Disorder  United States
# 2                      Symptoms of Depressive Disorder  United States
# 3                      Symptoms of Depressive Disorder  United States
# 4                      Symptoms of Depressive Disorder  United States
# ..                                                 ...            ...
# 205  Symptoms of Anxiety Disorder or Depressive Dis...       Virginia
# 206  Symptoms of Anxiety Disorder or Depressive Dis...     Washington
# 207  Symptoms of Anxiety Disorder or Depressive Dis...  West Virginia
# 208  Symptoms of Anxiety Disorder or Depressive Dis...      Wisconsin
# 209  Symptoms of Anxiety Disorder or Depressive Dis...        Wyoming
#
#     Time Period Start Date  Value
# 0           4/23/2020 0:00   23.5
# 1           4/23/2020 0:00   32.7
# ...

# %%
#Calculate average anxiety level as of 04/23/20
avg_anx_042320 = (anx_042320_df["Value"]).mean()
avg_anx_042320_df = pd.DataFrame({"Average American anxiety level as of 04/23/20": [avg_anx_042320]})
avg_anx_042320_df
# Out:
#    Average American anxiety level as of 04/23/20
# 0                                      29.150952

# %%
anx_093020_df = anx_data.loc[anx_data["Time Period Start Date"] == "9/30/2020 0:00", :]
anx_093020_df.head()
# Out:
#                             Indicator          State Time Period Start Date  \
# 3207  Symptoms of Depressive Disorder  United States         9/30/2020 0:00
# 3208  Symptoms of Depressive Disorder  United States         9/30/2020 0:00
# 3209  Symptoms of Depressive Disorder  United States         9/30/2020 0:00
# 3210  Symptoms of Depressive Disorder  United States         9/30/2020 0:00
# 3211  Symptoms of Depressive Disorder  United States         9/30/2020 0:00
#
#       Value
# 3207   25.4
# 3208   39.3
# 3209   28.4
# 3210   26.4
# 3211   22.6

# %%
avg_anx_093020 = (anx_093020_df["Value"]).mean()
avg_anx_093020_df = pd.DataFrame({"Average American anxiety level as of 09/30/20": [avg_anx_093020]})
avg_anx_093020_df
# Out:
#    Average American anxiety level as of 09/30/20
# 0                                      30.998095

# %%
anx_031721_df = anx_data.loc[anx_data["Time Period Start Date"] == "3/17/2021 0:00", :]
anx_031721_df.head()
# Out:
#                             Indicator          State Time Period Start Date  \
# 5574  Symptoms of Depressive Disorder  United States         3/17/2021 0:00
# 5575  Symptoms of Depressive Disorder  United States         3/17/2021 0:00
# 5576  Symptoms of Depressive Disorder  United States         3/17/2021 0:00
# 5577  Symptoms of Depressive Disorder  United States         3/17/2021 0:00
# 5578  Symptoms of Depressive Disorder  United States         3/17/2021 0:00
#
#       Value
# 5574   24.6
# 5575   38.2
# 5576   28.2
# 5577   25.0
# 5578   22.5

# %%
avg_anx_031721 = (anx_031721_df["Value"]).mean()
avg_anx_031721_df = pd.DataFrame({"Average American anxiety level as of 03/17/21": [avg_anx_031721]})
avg_anx_031721_df
# Out:
#    Average American anxiety level as of 03/17/21
# 0                                      29.451905
