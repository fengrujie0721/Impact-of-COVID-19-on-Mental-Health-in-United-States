# %%
import pandas as pd
import matplotlib.pyplot as plt
# Files to Load
file1_to_load = "Resources/us_states.csv"
file2_to_load = "Resources/Anxiety_data.csv"

# Read CSV Files and store into Pandas data frames
covid_data = pd.read_csv(file1_to_load)
anxiety_data = pd.read_csv(file2_to_load)

#Display DataFrames for Covid and Anxiety data
display('Covid Data:', covid_data.head())
display('Anxiety Data:',anxiety_data.head())
# Out:
# 'Covid Data:'
#         date       state  fips  cases  deaths
# 0  1/21/2020  Washington    53      1       0
# 1  1/22/2020  Washington    53      1       0
# 2  1/23/2020  Washington    53      1       0
# 3  1/24/2020    Illinois    17      1       0
# 4  1/24/2020  Washington    53      1       0
# 'Anxiety Data:'
#                          Indicator              Group          State  \
# 0  Symptoms of Depressive Disorder  National Estimate  United States
# 1  Symptoms of Depressive Disorder             By Age  United States
# 2  Symptoms of Depressive Disorder             By Age  United States
# 3  Symptoms of Depressive Disorder             By Age  United States
# 4  Symptoms of Depressive Disorder             By Age  United States
#
#         Subgroup Phase  Time Period Time Period Label Time Period Start Date  \
# 0  United States     1            1    Apr 23 - May 5         4/23/2020 0:00
# 1  18 - 29 years     1            1    Apr 23 - May 5         4/23/2020 0:00
# 2  30 - 39 years     1            1    Apr 23 - May 5         4/23/2020 0:00
# 3  40 - 49 years     1            1    Apr 23 - May 5         4/23/2020 0:00
# 4  50 - 59 years     1            1    Apr 23 - May 5         4/23/2020 0:00
#
#   Time Period End Date  Value  Low CI  High CI Confidence Interval  \
# 0        5/5/2020 0:00   23.5    22.7     24.3         22.7 - 24.3
# 1        5/5/2020 0:00   32.7    30.2     35.2         30.2 - 35.2
# 2        5/5/2020 0:00   25.7    24.1     27.3         24.1 - 27.3
# 3        5/5/2020 0:00   24.8    23.3     26.2         23.3 - 26.2
# 4        5/5/2020 0:00   23.2    21.5     25.0         21.5 - 25.0
#
#   Quartile Range
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
del covid_data['fips']
covid_data
# Out:
#             date          state   cases  deaths
# 0      1/21/2020     Washington       1       0
# 1      1/22/2020     Washington       1       0
# 2      1/23/2020     Washington       1       0
# 3      1/24/2020       Illinois       1       0
# 4      1/24/2020     Washington       1       0
# ...          ...            ...     ...     ...
# 23054  4/25/2021       Virginia  654210   10691
# 23055  4/25/2021     Washington  397006    5478
# 23056  4/25/2021  West Virginia  151382    2821
# 23057  4/25/2021      Wisconsin  656668    7473
# 23058  4/25/2021        Wyoming   57696     705
#
# [23059 rows x 4 columns]

# %%
del anxiety_data['Group']
del anxiety_data['Subgroup']
del anxiety_data['Phase']
del anxiety_data['Time Period']
del anxiety_data['Time Period Label']
del anxiety_data['Time Period End Date']
del anxiety_data['Low CI']
del anxiety_data['High CI']
del anxiety_data['Confidence Interval']
del anxiety_data['Quartile Range']

#change the date format of anxiety_data to match covid_data's
anxiety_data['Time Period Start Date'] = anxiety_data['Time Period Start Date'].apply(lambda dateStr:dateStr.split()[0])

#change column names to assist merge and be meaningful
anxiety_data_renamed = anxiety_data.rename(columns={'State':'state',"Indicator":"mental disorder","Value":"frequency of mental disorder","Time Period Start Date":"date"})
anxiety_data_renamed
# Out:
#                                         mental disorder          state  \
# 0                       Symptoms of Depressive Disorder  United States
# 1                       Symptoms of Depressive Disorder  United States
# 2                       Symptoms of Depressive Disorder  United States
# 3                       Symptoms of Depressive Disorder  United States
# 4                       Symptoms of Depressive Disorder  United States
# ...                                                 ...            ...
# 5779  Symptoms of Anxiety Disorder or Depressive Dis...       Virginia
# 5780  Symptoms of Anxiety Disorder or Depressive Dis...     Washington
# 5781  Symptoms of Anxiety Disorder or Depressive Dis...  West Virginia
# 5782  Symptoms of Anxiety Disorder or Depressive Dis...      Wisconsin
# 5783  Symptoms of Anxiety Disorder or Depressive Dis...        Wyoming
#
#            date  frequency of mental disorder
# 0     4/23/2020                          23.5
# 1     4/23/2020                          32.7
# 2     4/23/2020                          25.7
# 3     4/23/2020                          24.8
# 4     4/23/2020                          23.2
# ...         ...                           ...
# 5779  3/17/2021                          31.4
# 5780  3/17/2021                          35.6
# 5781  3/17/2021                          41.0
# 5782  3/17/2021                          32.3
# 5783  3/17/2021                          35.6
#
# [5784 rows x 4 columns]

# %%
#merge data based on states
merged_data = covid_data.merge(anxiety_data_renamed,how="inner", on = ["state","date"])
merged_data
# Out:
#            date      state   cases  deaths  \
# 0     4/23/2020    Alabama    5832     197
# 1     4/23/2020    Alabama    5832     197
# 2     4/23/2020    Alabama    5832     197
# 3     4/23/2020     Alaska     335       7
# 4     4/23/2020     Alaska     335       7
# ...         ...        ...     ...     ...
# 4126  3/17/2021  Wisconsin  627266    7203
# 4127  3/17/2021  Wisconsin  627266    7203
# 4128  3/17/2021    Wyoming   55449     693
# 4129  3/17/2021    Wyoming   55449     693
# 4130  3/17/2021    Wyoming   55449     693
#
#                                         mental disorder  \
# 0                       Symptoms of Depressive Disorder
# 1                          Symptoms of Anxiety Disorder
# 2     Symptoms of Anxiety Disorder or Depressive Dis...
# 3                       Symptoms of Depressive Disorder
# 4                          Symptoms of Anxiety Disorder
# ...                                                 ...
# 4126                       Symptoms of Anxiety Disorder
# 4127  Symptoms of Anxiety Disorder or Depressive Dis...
# 4128                    Symptoms of Depressive Disorder
# 4129                       Symptoms of Anxiety Disorder
# 4130  Symptoms of Anxiety Disorder or Depressive Dis...
#
#       frequency of mental disorder
# 0                             18.6
# 1                             25.6
# 2                             30.3
# 3                             19.2
# 4                             27.7
# ...                            ...
# 4126                          25.9
# 4127                          32.3
# 4128                          24.2
# 4129                          30.1
# 4130                          35.6
#
# [4131 rows x 6 columns]

# %%
date_range = merged_data["date"].unique()
date_range
# Out:
# array(['4/23/2020', '5/7/2020', '5/14/2020', '5/21/2020', '5/28/2020',
#        '6/4/2020', '6/11/2020', '6/18/2020', '6/25/2020', '7/2/2020',
#        '7/9/2020', '7/16/2020', '8/19/2020', '9/2/2020', '9/16/2020',
#        '9/30/2020', '10/14/2020', '10/28/2020', '11/11/2020',
#        '11/25/2020', '12/9/2020', '1/6/2021', '1/20/2021', '2/3/2021',
#        '2/17/2021', '3/3/2021', '3/17/2021'], dtype=object)

# %%
#April anxiety
anx_april_df = merged_data.loc[merged_data["date"] =="4/23/2020", :]
anx_april_df.head()
# Out:
#         date    state  cases  deaths  \
# 0  4/23/2020  Alabama   5832     197
# 1  4/23/2020  Alabama   5832     197
# 2  4/23/2020  Alabama   5832     197
# 3  4/23/2020   Alaska    335       7
# 4  4/23/2020   Alaska    335       7
#
#                                      mental disorder  \
# 0                    Symptoms of Depressive Disorder
# 1                       Symptoms of Anxiety Disorder
# 2  Symptoms of Anxiety Disorder or Depressive Dis...
# 3                    Symptoms of Depressive Disorder
# 4                       Symptoms of Anxiety Disorder
#
#    frequency of mental disorder
# 0                          18.6
# 1                          25.6
# 2                          30.3
# 3                          19.2
# 4                          27.7

# %%
#May anxiety (I wanted to sort 5/7 ~ 5/28 but multiple array did not work so I just picked 5/28)
anx_may_df = merged_data.loc[merged_data["date"] == "5/28/2020", :]
anx_may_df.head()
# Out:
#           date    state  cases  deaths  \
# 612  5/28/2020  Alabama  16530     591
# 613  5/28/2020  Alabama  16530     591
# 614  5/28/2020  Alabama  16530     591
# 615  5/28/2020   Alaska    430       8
# 616  5/28/2020   Alaska    430       8
#
#                                        mental disorder  \
# 612                    Symptoms of Depressive Disorder
# 613                       Symptoms of Anxiety Disorder
# 614  Symptoms of Anxiety Disorder or Depressive Dis...
# 615                    Symptoms of Depressive Disorder
# 616                       Symptoms of Anxiety Disorder
#
#      frequency of mental disorder
# 612                          28.4
# 613                          31.6
# 614                          37.5
# 615                          24.4
# 616                          26.1

# %%
anx_jun_df = merged_data.loc[merged_data["date"] == "6/25/2020", :]
anx_july_df = merged_data.loc[merged_data["date"] == "7/16/2020", :]
anx_aug_df = merged_data.loc[merged_data["date"] == "8/19/2020", :]
anx_sep_df = merged_data.loc[merged_data["date"] == "9/30/2020", :]
anx_oct_df = merged_data.loc[merged_data["date"] == "10/28/2020", :]
anx_nov_df = merged_data.loc[merged_data["date"] == "11/25/2020", :]
anx_dec_df = merged_data.loc[merged_data["date"] == "12/9/2020", :]
anx_jan_df = merged_data.loc[merged_data["date"] == "1/20/2021", :]
anx_feb_df = merged_data.loc[merged_data["date"] == "2/17/2021", :]
anx_march_df = merged_data.loc[merged_data["date"] == "3/17/2021", :]

# %%
mean_april_anx = (anx_april_df["frequency of mental disorder"]).mean()
mean_may_anx = (anx_may_df["frequency of mental disorder"]).mean()
mean_jun_anx = (anx_jun_df["frequency of mental disorder"]).mean()
mean_july_anx = (anx_july_df["frequency of mental disorder"]).mean()
mean_aug_anx = (anx_aug_df["frequency of mental disorder"]).mean()
mean_sep_anx = (anx_sep_df["frequency of mental disorder"]).mean()
mean_oct_anx = (anx_oct_df["frequency of mental disorder"]).mean()
mean_nov_anx = (anx_nov_df["frequency of mental disorder"]).mean()
mean_dec_anx = (anx_dec_df["frequency of mental disorder"]).mean()
mean_jan_anx = (anx_jan_df["frequency of mental disorder"]).mean()
mean_feb_anx = (anx_feb_df["frequency of mental disorder"]).mean()
mean_march_anx = (anx_march_df["frequency of mental disorder"]).mean()
US_Anxiety_bymonth_df = pd.DataFrame({"April": [mean_april_anx],
                                "May": [mean_may_anx],
                                "Jun": [mean_jun_anx],
                                "July": [mean_july_anx],
                                "August": [mean_aug_anx],
                                "September": [mean_sep_anx],
                                "October": [mean_oct_anx],
                                "November": [mean_nov_anx],
                                "December": [mean_dec_anx],
                                "January": [mean_jan_anx],
                                "February": [mean_feb_anx],
                                "March": [mean_march_anx]
                                
}
)

US_Anxiety_bymonth_df
# Out:
#       April        May        Jun       July     August  September    October  \
# 0  28.80719  29.051634  31.801307  34.953595  29.809804  30.875163  34.720261
#
#    November  December    January   February      March
# 0  35.22549  35.79085  34.068627  32.243137  29.190196

# %%
anx_frame_df = pd.DataFrame({
    "Months" : ["April 2020", "May", "Jun", "July", "August", "September", "October", "November", "December", "January 2021", "February 2021", "March"],
    "Frequency of mental disorder" :[28.80719, 29.051634, 31.801307, 34.953595, 29.809804, 30.875163, 34.720261, 35.22549, 35.79085, 34.068627, 32.243137, 29.190196]
})
anx_frame_df
# Out:
#            Months  Frequency of mental disorder
# 0      April 2020                     28.807190
# 1             May                     29.051634
# 2             Jun                     31.801307
# 3            July                     34.953595
# 4          August                     29.809804
# 5       September                     30.875163
# 6         October                     34.720261
# 7        November                     35.225490
# 8        December                     35.790850
# 9    January 2021                     34.068627
# 10  February 2021                     32.243137
# 11          March                     29.190196

# %%
chart_anx = pd.DataFrame(anx_frame_df.groupby(["Months"]).count()).reset_index()
chart_anx_df = anx_frame_df[["Months", "Frequency of mental disorder"]]
chart_anx_df = chart_anx_df.set_index("Months")

chart_anx_df.plot(kind="line", figsize=(20,10))
plt.title("US anxiety change by months")
plt.ylabel("Frequency of mental disorder")
plt.show()

# %%
anx_group_state_df = merged_data.groupby(["state"])
anx_mean_state = anx_group_state_df.mean()
anx_mean_state.head()
# Out:
#                    cases        deaths  frequency of mental disorder
# state
# Alabama     1.739869e+05   3081.555556                     32.496296
# Alaska      1.789378e+04     86.259259                     31.638272
# Arizona     2.708545e+05   5512.000000                     33.493827
# Arkansas    1.061795e+05   1719.148148                     34.324691
# California  1.112002e+06  17291.148148                     34.827160

# %%
del anx_mean_state['cases']
del anx_mean_state['deaths']
anx_mean_state
# Out:
#                       frequency of mental disorder
# state
# Alabama                                  32.496296
# Alaska                                   31.638272
# Arizona                                  33.493827
# Arkansas                                 34.324691
# California                               34.827160
# Colorado                                 32.427160
# Connecticut                              31.117284
# Delaware                                 29.080247
# District of Columbia                     32.238272
# Florida                                  33.549383
# Georgia                                  33.041975
# Hawaii                                   29.533333
# Idaho                                    29.946914
# Illinois                                 32.427160
# Indiana                                  32.170370
# Iowa                                     28.340741
# Kansas                                   30.274074
# Kentucky                                 33.938272
# Louisiana                                37.044444
# Maine                                    30.232099
# Maryland                                 30.191358
# Massachusetts                            30.412346
# Michigan                                 31.230864
# Minnesota                                27.083951
# Mississippi                              36.120988
# Missouri                                 31.712346
# Montana                                  28.675309
# Nebraska                                 27.461728
# Nevada                                   36.228395
# New Hampshire                            29.277778
# New Jersey                               32.035802
# New Mexico                               35.223457
# New York                                 31.914815
# North Carolina                           30.746914
# North Dakota                             25.828395
# Ohio                                     32.040741
# Oklahoma                                 34.361728
# Oregon                                   35.254321
# Pennsylvania                             31.333333
# Rhode Island                             31.269136
# South Carolina                           30.746914
# South Dakota                             26.171605
# Tennessee                                32.632099
# Texas                                    34.237037
# Utah                                     30.929630
# Vermont                                  30.033333
# Virginia                                 30.360494
# Washington                               32.939506
# West Virginia                            34.466667
# Wisconsin                                27.592593
# Wyoming                                  29.077778

# %%
# Collect a list of all the unique values in "date"
unique_dates_list = covid_data["date"].unique()
unique_dates_list
# Out:
# array(['1/21/2020', '1/22/2020', '1/23/2020', '1/24/2020', '1/25/2020',
#        '1/26/2020', '1/27/2020', '1/28/2020', '1/29/2020', '1/30/2020',
#        '1/31/2020', '2/1/2020', '2/2/2020', '2/3/2020', '2/4/2020',
#        '2/5/2020', '2/6/2020', '2/7/2020', '2/8/2020', '2/9/2020',
#        '2/10/2020', '2/11/2020', '2/12/2020', '2/13/2020', '2/14/2020',
#        '2/15/2020', '2/16/2020', '2/17/2020', '2/18/2020', '2/19/2020',
#        '2/20/2020', '2/21/2020', '2/22/2020', '2/23/2020', '2/24/2020',
#        '2/25/2020', '2/26/2020', '2/27/2020', '2/28/2020', '2/29/2020',
#        '3/1/2020', '3/2/2020', '3/3/2020', '3/4/2020', '3/5/2020',
#        '3/6/2020', '3/7/2020', '3/8/2020', '3/9/2020', '3/10/2020',
#        '3/11/2020', '3/12/2020', '3/13/2020', '3/14/2020', '3/15/2020',
#        '3/16/2020', '3/17/2020', '3/18/2020', '3/19/2020', '3/20/2020',
#        '3/21/2020', '3/22/2020', '3/23/2020', '3/24/2020', '3/25/2020',
#        '3/26/2020', '3/27/2020', '3/28/2020', '3/29/2020', '3/30/2020',
#        '3/31/2020', '4/1/2020', '4/2/2020', '4/3/2020', '4/4/2020',
#        '4/5/2020', '4/6/2020', '4/7/2020', '4/8/2020', '4/9/2020',
#        '4/10/2020', '4/11/2020', '4/12/2020', '4/13/2020', '4/14/2020',
#        '4/15/2020', '4/16/2020', '4/17/2020', '4/18/2020', '4/19/2020',
#        '4/20/2020', '4/21/2020', '4/22/2020', '4/23/2020', '4/24/2020',
#        '4/25/2020', '4/26/2020', '4/27/2020', '4/28/2020', '4/29/2020',
#        '4/30/2020', '5/1/2020', '5/2/2020', '5/3/2020', '5/4/2020',
#        '5/5/2020', '5/6/2020', '5/7/2020', '5/8/2020', '5/9/2020',
#        '5/10/2020', '5/11/2020', '5/12/2020', '5/13/2020', '5/14/2020',
#        '5/15/2020', '5/16/2020', '5/17/2020', '5/18/2020', '5/19/2020',
#        '5/20/2020', '5/21/2020', '5/22/2020', '5/23/2020', '5/24/2020',
#        '5/25/2020', '5/26/2020', '5/27/2020', '5/28/2020', '5/29/2020',
#        '5/30/2020', '5/31/2020', '6/1/2020', '6/2/2020', '6/3/2020',
#        '6/4/2020', '6/5/2020', '6/6/2020', '6/7/2020', '6/8/2020',
#        '6/9/2020', '6/10/2020', '6/11/2020', '6/12/2020', '6/13/2020',
#        '6/14/2020', '6/15/2020', '6/16/2020', '6/17/2020', '6/18/2020',
#        '6/19/2020', '6/20/2020', '6/21/2020', '6/22/2020', '6/23/2020',
#        '6/24/2020', '6/25/2020', '6/26/2020', '6/27/2020', '6/28/2020',
#        '6/29/2020', '6/30/2020', '7/1/2020', '7/2/2020', '7/3/2020',
#        '7/4/2020', '7/5/2020', '7/6/2020', '7/7/2020', '7/8/2020',
#        '7/9/2020', '7/10/2020', '7/11/2020', '7/12/2020', '7/13/2020',
#        '7/14/2020', '7/15/2020', '7/16/2020', '7/17/2020', '7/18/2020',
#        '7/19/2020', '7/20/2020', '7/21/2020', '7/22/2020', '7/23/2020',
#        '7/24/2020', '7/25/2020', '7/26/2020', '7/27/2020', '7/28/2020',
#        '7/29/2020', '7/30/2020', '7/31/2020', '8/1/2020', '8/2/2020',
#        '8/3/2020', '8/4/2020', '8/5/2020', '8/6/2020', '8/7/2020',
#        '8/8/2020', '8/9/2020', '8/10/2020', '8/11/2020', '8/12/2020',
#        '8/13/2020', '8/14/2020', '8/15/2020', '8/16/2020', '8/17/2020',
#        '8/18/2020', '8/19/2020', '8/20/2020', '8/21/2020', '8/22/2020',
#        '8/23/2020', '8/24/2020', '8/25/2020', '8/26/2020', '8/27/2020',
#        '8/28/2020', '8/29/2020', '8/30/2020', '8/31/2020', '9/1/2020',
#        '9/2/2020', '9/3/2020', '9/4/2020', '9/5/2020', '9/6/2020',
#        '9/7/2020', '9/8/2020', '9/9/2020', '9/10/2020', '9/11/2020',
#        '9/12/2020', '9/13/2020', '9/14/2020', '9/15/2020', '9/16/2020',
#        '9/17/2020', '9/18/2020', '9/19/2020', '9/20/2020', '9/21/2020',
#        '9/22/2020', '9/23/2020', '9/24/2020', '9/25/2020', '9/26/2020',
#        '9/27/2020', '9/28/2020', '9/29/2020', '9/30/2020', '10/1/2020',
#        '10/2/2020', '10/3/2020', '10/4/2020', '10/5/2020', '10/6/2020',
#        '10/7/2020', '10/8/2020', '10/9/2020', '10/10/2020', '10/11/2020',
#        '10/12/2020', '10/13/2020', '10/14/2020', '10/15/2020',
#        '10/16/2020', '10/17/2020', '10/18/2020', '10/19/2020',
#        '10/20/2020', '10/21/2020', '10/22/2020', '10/23/2020',
#        '10/24/2020', '10/25/2020', '10/26/2020', '10/27/2020',
#        '10/28/2020', '10/29/2020', '10/30/2020', '10/31/2020',
#        '11/1/2020', '11/2/2020', '11/3/2020', '11/4/2020', '11/5/2020',
#        '11/6/2020', '11/7/2020', '11/8/2020', '11/9/2020', '11/10/2020',
#        '11/11/2020', '11/12/2020', '11/13/2020', '11/14/2020',
#        '11/15/2020', '11/16/2020', '11/17/2020', '11/18/2020',
#        '11/19/2020', '11/20/2020', '11/21/2020', '11/22/2020',
#        '11/23/2020', '11/24/2020', '11/25/2020', '11/26/2020',
#        '11/27/2020', '11/28/2020', '11/29/2020', '11/30/2020',
#        '12/1/2020', '12/2/2020', '12/3/2020', '12/4/2020', '12/5/2020',
#        '12/6/2020', '12/7/2020', '12/8/2020', '12/9/2020', '12/10/2020',
#        '12/11/2020', '12/12/2020', '12/13/2020', '12/14/2020',
#        '12/15/2020', '12/16/2020', '12/17/2020', '12/18/2020',
#        '12/19/2020', '12/20/2020', '12/21/2020', '12/22/2020',
#        '12/23/2020', '12/24/2020', '12/25/2020', '12/26/2020',
#        '12/27/2020', '12/28/2020', '12/29/2020', '12/30/2020',
#        '12/31/2020', '1/1/2021', '1/2/2021', '1/3/2021', '1/4/2021',
#        '1/5/2021', '1/6/2021', '1/7/2021', '1/8/2021', '1/9/2021',
#        '1/10/2021', '1/11/2021', '1/12/2021', '1/13/2021', '1/14/2021',
#        '1/15/2021', '1/16/2021', '1/17/2021', '1/18/2021', '1/19/2021',
#        '1/20/2021', '1/21/2021', '1/22/2021', '1/23/2021', '1/24/2021',
#        '1/25/2021', '1/26/2021', '1/27/2021', '1/28/2021', '1/29/2021',
#        '1/30/2021', '1/31/2021', '2/1/2021', '2/2/2021', '2/3/2021',
#        '2/4/2021', '2/5/2021', '2/6/2021', '2/7/2021', '2/8/2021',
#        '2/9/2021', '2/10/2021', '2/11/2021', '2/12/2021', '2/13/2021',
#        '2/14/2021', '2/15/2021', '2/16/2021', '2/17/2021', '2/18/2021',
#        '2/19/2021', '2/20/2021', '2/21/2021', '2/22/2021', '2/23/2021',
#        '2/24/2021', '2/25/2021', '2/26/2021', '2/27/2021', '2/28/2021',
#        '3/1/2021', '3/2/2021', '3/3/2021', '3/4/2021', '3/5/2021',
#        '3/6/2021', '3/7/2021', '3/8/2021', '3/9/2021', '3/10/2021',
#        '3/11/2021', '3/12/2021', '3/13/2021', '3/14/2021', '3/15/2021',
#        '3/16/2021', '3/17/2021', '3/18/2021', '3/19/2021', '3/20/2021',
#        '3/21/2021', '3/22/2021', '3/23/2021', '3/24/2021', '3/25/2021',
#        '3/26/2021', '3/27/2021', '3/28/2021', '3/29/2021', '3/30/2021',
#        '3/31/2021', '4/1/2021', '4/2/2021', '4/3/2021', '4/4/2021',
#        '4/5/2021', '4/6/2021', '4/7/2021', '4/8/2021', '4/9/2021',
#        '4/10/2021', '4/11/2021', '4/12/2021', '4/13/2021', '4/14/2021',
#        '4/15/2021', '4/16/2021', '4/17/2021', '4/18/2021', '4/19/2021',
#        '4/20/2021', '4/21/2021', '4/22/2021', '4/23/2021', '4/24/2021',
#        '4/25/2021'], dtype=object)

# %%
# 03/01/2020
covid_030120_df = covid_data.loc[covid_data["date"] =="3/1/2020", :]
covid_030120_df.head()
# Out:
#          date          state  cases  deaths
# 240  3/1/2020        Arizona      1       0
# 241  3/1/2020     California     33       0
# 242  3/1/2020        Florida      2       0
# 243  3/1/2020       Illinois      3       0
# 244  3/1/2020  Massachusetts      1       0

# %%
# Sort the DataFrame by "deaths" in ascending order
covid_030120_df = covid_030120_df.sort_values("deaths")
covid_030120_df
# Out:
#          date          state  cases  deaths
# 240  3/1/2020        Arizona      1       0
# 241  3/1/2020     California     33       0
# 242  3/1/2020        Florida      2       0
# 243  3/1/2020       Illinois      3       0
# 244  3/1/2020  Massachusetts      1       0
# 245  3/1/2020       Nebraska     13       0
# 246  3/1/2020       New York      1       0
# 247  3/1/2020         Oregon      2       0
# 248  3/1/2020   Rhode Island      2       0
# 249  3/1/2020          Texas     11       0
# 250  3/1/2020           Utah      1       0
# 252  3/1/2020      Wisconsin      1       0
# 251  3/1/2020     Washington     17       3

# %%
# Calculate total deaths as of 03/01/2020
total_deaths_030120 = (covid_030120_df["deaths"]).sum()
total_deaths_030120_df = pd.DataFrame({"Total deaths from COVID-19 as of 03/01/2020 in US": [total_deaths_030120]})
total_deaths_030120_df
# Out:
#    Total deaths from COVID-19 as of 03/01/2020 in US
# 0                                                  3

# %%
chart_030120 = pd.DataFrame(covid_030120_df.groupby(["state"]).count()).reset_index()
chart_030120_df = covid_030120_df[["state", "deaths"]]
chart_030120_df = chart_030120_df.set_index("state")

chart_030120_df.plot(kind="bar", figsize=(20,10))
plt.title("Total deaths from COVID-19 as of 03/01/2020 by each state")
plt.ylabel("Total deaths")
plt.show()

# %%
# Looking only at 04/23/2020
covid_042320_df = covid_data.loc[covid_data["date"] =="4/23/2020", :]
covid_042320_df.head()
# Out:
#            date       state  cases  deaths
# 2819  4/23/2020     Alabama   5832     197
# 2820  4/23/2020      Alaska    335       7
# 2821  4/23/2020     Arizona   5769     257
# 2822  4/23/2020    Arkansas   2599      45
# 2823  4/23/2020  California  39534    1548

# %%
# Sort the DataFrame by "deaths" in ascending order
covid_042320_df = covid_042320_df.sort_values("deaths")
covid_042320_df
# Out:
#            date                     state   cases  deaths
# 2855  4/23/2020  Northern Mariana Islands      14       2
# 2868  4/23/2020            Virgin Islands      54       3
# 2830  4/23/2020                      Guam     979       6
# 2873  4/23/2020                   Wyoming     453       7
# 2820  4/23/2020                    Alaska     335       7
# 2863  4/23/2020              South Dakota    1956       9
# 2831  4/23/2020                    Hawaii     590      12
# 2846  4/23/2020                   Montana     442      14
# 2854  4/23/2020              North Dakota     709      15
# 2871  4/23/2020             West Virginia     981      31
# 2866  4/23/2020                      Utah    3621      35
# 2867  4/23/2020                   Vermont     825      42
# 2839  4/23/2020                     Maine     937      44
# 2822  4/23/2020                  Arkansas    2599      45
# 2847  4/23/2020                  Nebraska    2190      46
# 2849  4/23/2020             New Hampshire    1670      51
# 2832  4/23/2020                     Idaho    1836      54
# 2860  4/23/2020               Puerto Rico    1230      69
# 2851  4/23/2020                New Mexico    2379      78
# 2858  4/23/2020                    Oregon    2127      83
# 2826  4/23/2020                  Delaware    3308      92
# 2835  4/23/2020                      Iowa    3939      96
# 2836  4/23/2020                    Kansas    2626     112
# 2827  4/23/2020      District of Columbia    3361     139
# 2862  4/23/2020            South Carolina    4917     150
# 2864  4/23/2020                 Tennessee    8169     172
# 2857  4/23/2020                  Oklahoma    3017     179
# 2861  4/23/2020              Rhode Island    6256     189
# 2837  4/23/2020                  Kentucky    3548     194
# 2848  4/23/2020                    Nevada    4208     195
# 2819  4/23/2020                   Alabama    5832     197
# 2843  4/23/2020                 Minnesota    2942     200
# 2844  4/23/2020               Mississippi    5153     201
# 2845  4/23/2020                  Missouri    6321     248
# 2853  4/23/2020            North Carolina    7608     253
# 2821  4/23/2020                   Arizona    5769     257
# 2872  4/23/2020                 Wisconsin    5125     257
# 2869  4/23/2020                  Virginia   10999     375
# 2824  4/23/2020                  Colorado   11262     557
# 2865  4/23/2020                     Texas   22706     601
# 2856  4/23/2020                      Ohio   14694     656
# 2870  4/23/2020                Washington   12981     717
# 2840  4/23/2020                  Maryland   15805     748
# 2834  4/23/2020                   Indiana   13196     811
# 2829  4/23/2020                   Georgia   20905     871
# 2828  4/23/2020                   Florida   29640     986
# 2823  4/23/2020                California   39534    1548
# 2838  4/23/2020                 Louisiana   25798    1599
# 2825  4/23/2020               Connecticut   23100    1639
# 2833  4/23/2020                  Illinois   36935    1696
# 2859  4/23/2020              Pennsylvania   38334    1723
# 2841  4/23/2020             Massachusetts   46023    2360
# 2842  4/23/2020                  Michigan   35253    2977
# 2850  4/23/2020                New Jersey   99989    5368
# 2852  4/23/2020                  New York  267932   20212

# %%
# Calculate total deaths as of 04/23/2020
total_deaths_042320 = (covid_042320_df["deaths"]).sum()
total_deaths_042320_df = pd.DataFrame({"Total deaths from COVID-19 as of 04/23/2020 in US": [total_deaths_042320]})
total_deaths_042320_df
# Out:
#    Total deaths from COVID-19 as of 04/23/2020 in US
# 0                                              49228

# %%
chart_042320 = pd.DataFrame(covid_042320_df.groupby(["state"]).count()).reset_index()
chart_042320_df = covid_042320_df[["state", "deaths"]]
chart_042320_df = chart_042320_df.set_index("state")

chart_042320_df.plot(kind="bar", figsize=(20,10))
plt.title("Total deaths from COVID-19 as of 04/23/2020 by each state")
plt.ylabel("Total deaths")
plt.show()

# %%
# Looking only at 03/17/2021
covid_031721_df = covid_data.loc[covid_data["date"] =="3/17/2021", :]
covid_031721_df.head()
# Out:
#             date       state    cases  deaths
# 20859  3/17/2021     Alabama   509476   10363
# 20860  3/17/2021      Alaska    60451     293
# 20861  3/17/2021     Arizona   834329   16586
# 20862  3/17/2021    Arkansas   327781    5507
# 20863  3/17/2021  California  3631735   56952

# %%
# Sort the DataFrame by "deaths" in ascending order
covid_031721_df = covid_031721_df.sort_values("deaths")
covid_031721_df
# Out:
#             date                     state    cases  deaths
# 20895  3/17/2021  Northern Mariana Islands      157       2
# 20908  3/17/2021            Virgin Islands     2767      25
# 20870  3/17/2021                      Guam     8745     135
# 20907  3/17/2021                   Vermont    17106     217
# 20860  3/17/2021                    Alaska    60451     293
# 20871  3/17/2021                    Hawaii    28423     448
# 20913  3/17/2021                   Wyoming    55449     693
# 20879  3/17/2021                     Maine    47591     725
# 20867  3/17/2021      District of Columbia    42811    1044
# 20889  3/17/2021             New Hampshire    79367    1202
# 20886  3/17/2021                   Montana   102602    1398
# 20894  3/17/2021              North Dakota   101315    1490
# 20866  3/17/2021                  Delaware    91123    1516
# 20903  3/17/2021              South Dakota   114966    1915
# 20872  3/17/2021                     Idaho   176589    1937
# 20906  3/17/2021                      Utah   379838    2037
# 20900  3/17/2021               Puerto Rico   136893    2083
# 20887  3/17/2021                  Nebraska   205896    2238
# 20898  3/17/2021                    Oregon   160348    2358
# 20911  3/17/2021             West Virginia   136334    2565
# 20901  3/17/2021              Rhode Island   132184    2588
# 20891  3/17/2021                New Mexico   188907    3874
# 20897  3/17/2021                  Oklahoma   433516    4788
# 20876  3/17/2021                    Kansas   301763    4837
# 20888  3/17/2021                    Nevada   300177    5148
# 20877  3/17/2021                  Kentucky   421780    5197
# 20910  3/17/2021                Washington   354906    5212
# 20862  3/17/2021                  Arkansas   327781    5507
# 20875  3/17/2021                      Iowa   344268    5668
# 20864  3/17/2021                  Colorado   447840    6136
# 20883  3/17/2021                 Minnesota   500030    6824
# 20884  3/17/2021               Mississippi   301602    6936
# 20912  3/17/2021                 Wisconsin   627266    7203
# 20865  3/17/2021               Connecticut   294328    7807
# 20880  3/17/2021                  Maryland   395817    8099
# 20885  3/17/2021                  Missouri   580040    8806
# 20902  3/17/2021            South Carolina   536100    8933
# 20878  3/17/2021                 Louisiana   439002    9955
# 20909  3/17/2021                  Virginia   598468   10154
# 20859  3/17/2021                   Alabama   509476   10363
# 20904  3/17/2021                 Tennessee   781593   11555
# 20893  3/17/2021            North Carolina   894250   11783
# 20874  3/17/2021                   Indiana   677705   12893
# 20861  3/17/2021                   Arizona   834329   16586
# 20881  3/17/2021             Massachusetts   606377   16732
# 20882  3/17/2021                  Michigan   680273   16800
# 20869  3/17/2021                   Georgia  1013340   17801
# 20896  3/17/2021                      Ohio   993681   17992
# 20873  3/17/2021                  Illinois  1217258   23255
# 20890  3/17/2021                New Jersey   848875   24004
# 20899  3/17/2021              Pennsylvania   979065   24749
# 20868  3/17/2021                   Florida  1989016   32503
# 20905  3/17/2021                     Texas  2742767   47000
# 20892  3/17/2021                  New York  1762032   48686
# 20863  3/17/2021                California  3631735   56952

# %%
# Calculate total deaths as of 03/17/2021
total_deaths_031721 = (covid_031721_df["deaths"]).sum()
total_deaths_031721_df = pd.DataFrame({"Total deaths from COVID-19 as of 03/17/2021 in US": [total_deaths_031721]})
total_deaths_031721_df
# Out:
#    Total deaths from COVID-19 as of 03/17/2021 in US
# 0                                             537647

# %%
chart_031721 = pd.DataFrame(covid_031721_df.groupby(["state"]).count()).reset_index()
chart_031721_df = covid_031721_df[["state", "deaths"]]
chart_031721_df = chart_031721_df.set_index("state")

chart_031721_df.plot(kind="bar", figsize=(20,10))
plt.title("Total deaths from COVID-19 as of 03/17/2021 by each state")
plt.ylabel("Total deaths")
plt.show()

# %%
# Looking only at 4/25/2021 which is peak
covid_042521_df = covid_data.loc[covid_data["date"] =="4/25/2021", :]
covid_042521_df.head()
# Out:
#             date       state    cases  deaths
# 23004  4/25/2021     Alabama   526131   10851
# 23005  4/25/2021      Alaska    66518     318
# 23006  4/25/2021     Arizona   858737   17268
# 23007  4/25/2021    Arkansas   334706    5718
# 23008  4/25/2021  California  3731677   61434

# %%
# Sort the DataFrame by "deaths" in ascending order
covid_042521_df = covid_042521_df.sort_values("deaths")
covid_042521_df
# Out:
#             date                     state    cases  deaths
# 23040  4/25/2021  Northern Mariana Islands      164       2
# 23053  4/25/2021            Virgin Islands     3068      27
# 23015  4/25/2021                      Guam     8884     137
# 23052  4/25/2021                   Vermont    22576     244
# 23005  4/25/2021                    Alaska    66518     318
# 23016  4/25/2021                    Hawaii    32284     475
# 23058  4/25/2021                   Wyoming    57696     705
# 23024  4/25/2021                     Maine    59776     772
# 23012  4/25/2021      District of Columbia    47323    1099
# 23034  4/25/2021             New Hampshire    93821    1284
# 23039  4/25/2021              North Dakota   106719    1517
# 23031  4/25/2021                   Montana   108170    1563
# 23011  4/25/2021                  Delaware   103222    1616
# 23048  4/25/2021              South Dakota   121986    1958
# 23017  4/25/2021                     Idaho   186300    2033
# 23051  4/25/2021                      Utah   395495    2182
# 23045  4/25/2021               Puerto Rico   162074    2264
# 23032  4/25/2021                  Nebraska   218732    2358
# 23043  4/25/2021                    Oregon   180700    2497
# 23046  4/25/2021              Rhode Island   146324    2660
# 23056  4/25/2021             West Virginia   151382    2821
# 23036  4/25/2021                New Mexico   196221    4026
# 23021  4/25/2021                    Kansas   309544    5009
# 23033  4/25/2021                    Nevada   312840    5422
# 23055  4/25/2021                Washington   397006    5478
# 23007  4/25/2021                  Arkansas   334706    5718
# 23020  4/25/2021                      Iowa   362923    5927
# 23009  4/25/2021                  Colorado   504495    6388
# 23022  4/25/2021                  Kentucky   444211    6557
# 23042  4/25/2021                  Oklahoma   446550    6716
# 23028  4/25/2021                 Minnesota   568321    7157
# 23029  4/25/2021               Mississippi   310349    7175
# 23057  4/25/2021                 Wisconsin   656668    7473
# 23010  4/25/2021               Connecticut   334766    8047
# 23025  4/25/2021                  Maryland   443443    8661
# 23030  4/25/2021                  Missouri   597547    9180
# 23047  4/25/2021            South Carolina   574985    9430
# 23023  4/25/2021                 Louisiana   455541   10336
# 23054  4/25/2021                  Virginia   654210   10691
# 23004  4/25/2021                   Alabama   526131   10851
# 23049  4/25/2021                 Tennessee   826672   12045
# 23038  4/25/2021            North Carolina   963886   12553
# 23019  4/25/2021                   Indiana   718090   13274
# 23006  4/25/2021                   Arizona   858737   17268
# 23026  4/25/2021             Massachusetts   682784   17550
# 23027  4/25/2021                  Michigan   911145   18398
# 23041  4/25/2021                      Ohio  1064306   19122
# 23014  4/25/2021                   Georgia  1069495   19357
# 23018  4/25/2021                  Illinois  1324610   24139
# 23035  4/25/2021                New Jersey   997891   25380
# 23044  4/25/2021              Pennsylvania  1138529   26038
# 23013  4/25/2021                   Florida  2208576   34847
# 23050  4/25/2021                     Texas  2874344   50103
# 23037  4/25/2021                  New York  2029307   51471
# 23008  4/25/2021                California  3731677   61434

# %%
# Calculate total deaths as of 04/25/2021
total_deaths_042521 = (covid_042521_df["deaths"]).sum()
total_deaths_042521_df = pd.DataFrame({"Total deaths from COVID-19 as of 04/25/2021 in US": [total_deaths_042521]})
total_deaths_042521_df
# Out:
#    Total deaths from COVID-19 as of 04/25/2021 in US
# 0                                             571753

# %%
chart_042521 = pd.DataFrame(covid_042521_df.groupby(["state"]).count()).reset_index()
chart_042521_df = covid_042521_df[["state", "deaths"]]
chart_042521_df = chart_042521_df.set_index("state")

chart_042521_df.plot(kind="bar", figsize=(20,10))
plt.title("Total deaths from COVID-19 as of 04/25/2021 by each state")

plt.show()
